# %% [markdown]
# <a href="https://colab.research.google.com/github/Stoneboom/FunTech-ML-Training/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import io
from google.cloud import vision

client = vision.ImageAnnotatorClient.from_service_account_json("creds.json")

with io.open("cat.png", 'rb')as image_file:
  content = image_file.read()

image = vision.Image(content=content)

response = client.label_detection(image=image)
labels = response.label_annotations

for label in labels:
  print(label.description)
# Out:
# Cat
# Felidae
# Carnivores
# Felinae
# Whiskers
# Vertebrate
# Black cat
# Snout
# Collar
# Black

# %%
with io.open("people.jpg", 'rb') as image_file:
  content = image_file.read()

image = vision.Image(content=content)

response = client.face_detection(image=image)
faces = response.face_annotations

for face in faces:
  print(f"This person is {face.anger_likelihood} to be angry")
  print(f"This person is {face.joy_likelihood} to be happy")
  print(f"This person is {face.sorrow_likelihood} to be sad")
  print(f"This person is {face.surprise_likelihood} to be suprised\n")
# Out:
# This person is 1 to b angry
# This person is 5 to be happy
# This person is 1 to be sad
# This person is 1 to be suprised
#
# This person is 1 to b angry
# This person is 5 to be happy
# This person is 1 to be sad
# This person is 1 to be suprised
#
# This person is 1 to b angry
# This person is 1 to be happy
# This person is 1 to be sad
# This person is 1 to be suprised
#
# This person is 1 to b angry
# This person is 3 to be happy
# This person is 1 to be sad
# This person is 1 to be suprised
#
# This person is 1 to b angry
# This person is 5 to be happy
# This person is 1 to be sad
# This person is 1 to be suprised
#
# This person is 1 to b angry
# This person is 4 to be happy
# This person is 1 to be sad
# This person is 1 to be suprised
#
# This person is 1 to b angry
# This person is 5 to be happy
# This person is 1 to be sad
# This person is 1 to be suprised

# %%
with io.open("people.jpg", 'rb') as image_file:
  content = image_file.read()

image = vision.Image(content=content)

response = client.face_detection(image=image)
faces = response.face_annotations

for face in faces:
  print(f"This person is {face.anger_likelihood} to be angry")
  print(f"This person is {face.joy_likelihood} to be happy")
  print(f"This person is {face.sorrow_likelihood} to be sad")
  print(f"This person is {face.surprise_likelihood} to be suprised\n")

# %%
with io.open("landmark.jpg", 'rb') as image_file:
  content = image_file.read()

image = vision.Image(content=content)

response = client.landmark_detection(image=image)
landmarks = response.landmark_annotations

if len(landmarks) == 0:
  print("No landmark found")
else:
    for landmark in landmarks:
      print(f"This landmark is the {landmark.description}")
# Out:
# This landmark is the Leaning Tower Of Pisa

# %%
from google.cloud import language
from google.cloud.language_v1 import types

client = language.LanguageServiceClient.from_service_account_json("creds.json")
text = "I love cake"
document = types.Document(content=text, type=types.Document.Type.PLAIN_TEXT)

response = client.analyze_sentiment(document=document, encoding_type="UTF32")
sentences = response.sentences

for sentence in sentences:
  print(f"Sentence: {sentence.text.content}")
  print(f"Sentiment score: {sentence.sentiment.score}")
  print(f"Sentiment magnitude: {sentence.sentiment.magnitude}")
# Out:
# Sentence: I love diddy foids
# Sentiment score: 0.8999999761581421
# Sentiment magnitude: 0.8999999761581421

# %%
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Try installing tf-keras for compatibility if model was saved with TensorFlow 2.x Keras
from tf_keras.models import load_model

# Load the model
model = load_model("keras_model.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image
image = Image.open("cat.png").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array

# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# 1/1 [==============================] - 1s 887ms/step
# Class: Cat
# Confidence Score: 0.9999999

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout #

model = Sequential()
model.add(Dense(64,input_shape=(4,))) # Sets the amount of neurons,
                                      # and the amount of data entered

model.add(Activation('relu')) # Type of activation function that changes how the
                              # model trains/learns

model.add(Dropout(0.2)) # Adds regularisation. This is adding variation to
                         # prevent overfitting

model.add(Dense(64))

model.add(Activation('relu'))

model.add(Dense(2)) # Output node, here has two catagories (dog/cat)

model.add(Activation('softmax')) # Classification algo w/o linear relation
                                 # between classes
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ...

# %%
import csv
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from PIL import Image

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

# Array that will be fed in
label = []

feature = []

# open csv file and create reader
with open("tic-tac-toe.csv") as csv_file:
  csv_reader = csv.reader(csv_file)
  line = 0
  for row in csv_reader:
    if line != 0:  ## Ignore headers
      feat=[]
      feat.append(row[0])
      feat.append(row[1])
      feat.append(row[2])
      feat.append(row[3])
      feat.append(row[4])
      feat.append(row[5])
      feat.append(row[6])
      feat.append(row[7])
      feat.append(row[8])
      feature.append(feat)
      label.append(row[9]) # Last row contains classifications

    line += 1

def prep_inputs(features_list):
  oe = OrdinalEncoder()
  oe.fit(features_list)
  encoded = oe.transform(features_list)
  return encoded

def prep_labels(labels_list):
  le = LabelEncoder()
  le.fit(labels_list)
  encoded = le.transform(labels_list)
  return encoded

feature = prep_inputs(feature)
label = prep_labels(label)

feature = np.array(feature)
label = np.array(label)
label = to_categorical(label)

x_train, x_test, y_train, y_test = train_test_split(feature, label, test_size=0.15)

# %%
model = Sequential()
model.add(Dense(64,input_shape=(9,)))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(Dense(2, activation='softmax'))

# Loss checks correctness, optimizer uses loss value to train accuracy (adamn is algo)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=23)  # epochs is the amount it runs
# Out:
# Epoch 1/23
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.6290 - loss: 0.6463
# Epoch 2/23
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6818 - loss: 0.6043
# Epoch 3/23
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6892 - loss: 0.5915
# Epoch 4/23
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7064 - loss: 0.5828
# Epoch 5/23
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7064 - loss: 0.5766
# Epoch 6/23
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7236 - loss: 0.5565
# Epoch 7/23
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7310 - loss: 0.5363
# Epoch 8/23
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7383 - loss: 0.5385
# Epoch 9/23
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7518 - loss: 0.5266
# Epoch 10/23
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7494 - loss: 0.5133
# Epoch 11/23
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7604 - loss: 0.5093
# Epoch 12/23
# ...

# %%
result = model.evaluate(x_test, y_test)
print("Test Loss: ", result[0])
print("Test Accuracy: ", result[1])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.2662e-04
# Test Loss:  0.0008266223594546318
# Test Accuracy:  1.0

# %%
data = [[3.66, 8.50, -3.80, -0.44]]
data = np.array(data)
pred = model.predict(data)
print(pred.argmax())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# 0

# %%
# Start of new model w new dataset

from keras.datasets import mnist

# Flattening
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalisation
x_train = x_train / 255
x_test = x_test / 255
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Dense(64,input_shape=(784,))) # Size of each array member
model.add(Activation('relu'))
model.add(Dropout(0.2)) #  Useful with images
model.add(Dense(10))  # Digits 0-9, so 10
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8957 - loss: 0.3604
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9438 - loss: 0.1907
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9556 - loss: 0.1479
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9619 - loss: 0.1276
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9645 - loss: 0.1144
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9676 - loss: 0.1047
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9692 - loss: 0.0972
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9716 - loss: 0.0904
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9732 - loss: 0.0857
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9733 - loss: 0.0819

# %%
score = model.evaluate(x_test, y_test)
print("Test Loss: ", score[0])
print("Test Accuracy: ", score[1])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9749 - loss: 0.0895
# Test Loss:  0.08954169601202011
# Test Accuracy:  0.9749000072479248

# %%
test_image = Image.open("number.png").convert("L")
test_image = test_image.resize((28,28))
test_image = np.invert(test_image)
test_image = test_image.reshape(1, 784)
test_image = test_image.astype('float32')
test_image = test_image / 255
pred = model.predict(test_image)
print(pred.argmax())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3

# %%
model.save("digits_model.keras")

# %%
# Alternate approach ?

# Change reshape to
x_train = x_train.reshape(60000, 28, 28, 1)
x_test = x_test.reshape(10000, 28, 28, 1) # The one is colour dimension, in this case , greyscale

# Replace first dense layer w
model.add(layers.conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)))

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import csv

feature = []
label = []

# This is a regression problem rather than a clasification problem

# Coloumns 1-8 are useful
with open("mpg.csv") as csv_file:
  csv_reader = csv.reader(csv_file, delimiter=",")
  line = 0
  for row in csv_reader:
    if line != 0:
      feat = []
      feat.append(float(row[1]))
      feat.append(float(row[2]))
      feat.append(float(row[3]))
      feat.append(float(row[4]))
      feat.append(float(row[5]))
      feat.append(float(row[6]))
      feat.append(float(row[7]))
      feature.append(feat)
      label.append(float(row[0]))

    line += 1

feature = np.array(feature)
label = np.array(label)
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train, x_test, y_train, y_test = train_test_split(feature, label, test_size=0.25)

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential()
model.add(layers.Dense(512, activation='relu', input_dim=(7)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation="sigmoid"))  # Because one number in output

# Mean Squared Error - how far predictions are on average, squared
# Other is mean average error
model.compile(loss='mse', optimizer='adam', metrics=['mae'])
model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 566.0984 - mae: 22.4836
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 560.2564 - mae: 22.3418
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 560.2565 - mae: 22.3418
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 560.2565 - mae: 22.3418
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 560.2565 - mae: 22.3418
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 560.2564 - mae: 22.3418
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 560.2565 - mae: 22.3418
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 560.2565 - mae: 22.3418
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 560.2565 - mae: 22.3418
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 560.4464 - mae: 22.3452
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 560.2565 - mae: 22.3418
# Epoch 12/100
# ...

# %%
#model.predict(x_test[0])
model.evaluate(x_test, y_test)
print("MAE: ", score[0])
print("MSE: ", score[1])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 577.5585 - mae: 22.7582
# MAE:  0.08954169601202011
# MSE:  0.9749000072479248
